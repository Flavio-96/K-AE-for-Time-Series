# %%
from dtaidistance import dtw
from dtaidistance import dtw_visualisation as dtwvis
import numpy as np
s1 = np.array([0., 0, 1, 2, 1, 0, 1, 0, 0, 2, 1, 0, 0])
s2 = np.array([0., 1, 2, 3, 1, 0, 0, 0, 2, 1, 0, 0, 0])
path = dtw.warping_path(s1, s2)
dtwvis.plot_warping(s1, s2, path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-47d8d57b0842> in <module>
#       6 path = dtw.warping_path(s1, s2)
#       7 dtwvis.plot_warping(s1, s2, path)
# ----> 8 dtwvis.show()
#
# AttributeError: module 'dtaidistance.dtw_visualisation' has no attribute 'show'

# %%
distance = dtw.distance(s1, s2)
print(distance)
# Out:
# 1.4142135623730951
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-30072c290719> in <module>
#       1 distance = dtw.distance(s1, s2)
#       2 print(distance)
# ----> 3 s1.describe()
#
# AttributeError: 'list' object has no attribute 'describe'

# %%
dist = np.linalg.norm(s1 - s2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-81314516b037> in <module>
# ----> 1 dist = np.linalg.norm(s1 - s2)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
